# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt

#f_pop1_familiar_shuffled = '/home/brad/tmpdata/B1083_familiar_shuffled.pkl'
#f_pop1_familiar_shuffled = '/home/brad/DailyLog/20191113/JSpop_fast_B1083-1-1-10_LvsR-familiar-original.pkl'
f_pop1_familiar_shuffled = '/home/brad/DailyLog/20190314/JSpop_fast_B1083-1-1-20_LvsR-familiar-original.pkl'

# %%
with open(f_pop1_familiar_shuffled, 'rb') as f:
    divs = pickle.load(f)

# %%
plt.imshow(divs+divs.T)
