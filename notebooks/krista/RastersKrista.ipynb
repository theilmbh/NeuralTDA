# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import os
import sys
from ephys import core, events, rasters
from importlib import reload
import seaborn as sns
# %matplotlib inline
# Out:
# /home/brad/.conda/envs/neuraltda-3/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
block_path = '/home/brad/krista/B1083/P03S03/'
spikes     = core.load_spikes(block_path)
clusters   = core.load_clusters(block_path)
digmarks = events.load_events(block_path, 'DigMark')
fs         = core.load_fs(block_path)
trials     = events.load_trials(block_path)
rec        = 0

# %%
reload(rasters)
sns.set_style('white')
sns.set_context('poster')

f = plt.figure(figsize=(24, 11))
ax = plt.gca()
for trial in range(20):
    rasters.plot_raster_stim_trial(spikes, trials, clusters[0:75], 'L_40k', trial, [-2, 2], rec, fs, ax=ax)
    plt.tick_params(labelsize=36)
    plt.tick_params(size=10)
    plt.savefig('/home/brad/DailyLog/20170926/allcellraster{}.pdf'.format(trial))

# %%
from swissknife.streamtools import spectral
from scipy.io.wavfile import read

# %%
(rate, x) =read('/home/brad/L_40k.wav')
ax = plt.figure(figsize=(24, 11)).gca()
s = spectral.Spectrogram(x, rate, n_window=512, ax=ax).plot()
# Out:
# 5990.4
# fcut_plot 10000

# %%
s.plot()
plt.show()
# Out:
# 5990.4
# fcut_plot 10000
